# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/santu-bhoot/ML-intern/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I chose the Refresh / Content Opportunity Scoring lane because I want to investigate how available content and performance data can help identify which pages should be reviewed or refreshed first.
# The starter dataset contains information about search demand, impressions, clicks, traffic, content age, freshness, and performance trends, which makes this a practical problem to explore.
# My goal is to develop a useful way to prioritize content updates based on evidence rather than simply training a model for its own sake.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
#
# The decision I want to improve is which content pages should be prioritized for review and refresh.
# The content or SEO team would use the ranking to decide which pages to investigate and update first.
# A wrong recommendation could waste time and resources by refreshing a page that does not need improvement, while a more valuable page that needs attention may be missed.
# Therefore, the goal is to help the team prioritize its limited time and effort using evidence from the available data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("/content/ML-intern/data/raw/content_refresh_anonymized.csv")

print("Number of content pages:", len(df))

declining_pct = (df["trend_direction"].str.lower() == "down").mean() * 100
print(f"Pages with declining trends: {declining_pct:.1f}%")

print(f"Average content age: {df['content_age_days'].mean():.0f} days")
# Out:
# Number of content pages: 30000
# Pages with declining trends: 54.2%
# Average content age: 256 days

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This work can identify observed patterns and directional relationships in the available content and performance data. It can provide decision support by helping the content team prioritize which pages may be worth reviewing or refreshing first. However, the results will not prove that refreshing a page will directly cause its performance to improve. The analysis cannot establish causal relationships or predict exactly how Google will rank a page in the future. Any scoring or ranking should therefore be treated as a prioritization tool, not a guarantee of future performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
